# %% [markdown]
# ## UNet

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - UNet takes in image, and predicts noise applied to image
#     1. Embeds information about the input through convolution layers
#     2. Upsamples into the output to predict the noise applied to the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - UNets are also great because they can take in additional information
#     - e.g. Trainable embedding for timestep
#     - e.g. Trainable embedding for "context"
