# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - To control these models, we use embeddings
#     - e.g. we can use text caption to add context to the model. This is also how the image generation stuff learns to associate words with images
#     - Not only does adding context embeddings let the model associate words with images, it also lets you do embedding arithmetic such that it can generate images it has never seen before PURELY from arithmetic on text embeddings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - So in the model here, what is context?
#     - Context is anything that controls the generation of images
#     - It can be text embeddings (e.g. a few lines of text), or it can be categories
