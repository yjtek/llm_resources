# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Since LLMs can only inspect a limited number of words, we employ embeddings and vector stores

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - When we get a big document, we break it down into chunks
#     - Then take embeddings
#     - and store in vector database
#     - When given query, identify docs that are most similar
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Stuff method doesn't always work
#     - If documents are large, then it might not be possible
#
# - Some other options (i) mapreduce, (ii) iteratively refine
#
# ![image.png](attachment:image.png)
