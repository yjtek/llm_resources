# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Most models have no memory
#     - So you need to find a way to help the model remember previous parts of the convo
#
# - LLMs are STATELESS
#     - It only has memory insofar as you provide it information as part of the input

# %% [markdown]
# - ConversationBufferMemory vs ConversationBufferWindowMemory
#     - Once saves latest, the other saves window
#
# - ConversationSummaryBufferMemory
#     - Instead of restricting memory based on fixed number of token/exchanges, get the LLM to summarise the convo so far

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
