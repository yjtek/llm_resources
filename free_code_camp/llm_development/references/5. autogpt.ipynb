# %% [markdown]
# https://github.com/Significant-Gravitas/AutoGPT

# %% [markdown]
# - AutoGPT is an agent
#     - Given a prompt, it formulates a plan --> inputs an action --> prompts itself --> does stuff

# %% [markdown]
# - We want to train a model that can
#     - know what resources are available
#     - utilize resources
#     - plan how to use resources
#     - prompt itself to finish task without explicit programming

# %% [markdown]
# ![image.png](attachment:image.png)
